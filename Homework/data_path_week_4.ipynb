# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Description**:
# This scatter plot is showing Sepal Length vs Sepal Width of three Iris species("setosa," “versicolor,” and “virginica” ), X-axis is sepal length, and the y-axis is sepal width.
#
# The plot shows at least two obvious clusters of points. Since the dataset has three species of iris flowers, I suspect that this clustering might be due to species differentiation, each species is differentiated by the color of the point(orange/green/blue）. It is clearly seen that the Sepal lengths and widths are correlated for all three species but more so in the Setosa species， There are two clusters， also there are two species with overlapping Sepal lengths and widths.
#
#
# **Setosa**：this kind of iris, whose sepal length is smaller(under 6.0） but width is bigger（3.0 above) compared with the other two, and when the length is getting bigger the width is wider.
#
# **Versicolor**: this kind of iris, whose sepal length is between of other two species(5.0-7.0), and the width is generally smaller than the others, but there is overlapping between Versicolor and virginica, so there is more similarity for two of them.
#
# **virginica**: this kind of iris, whose sepal length most of the time is longest among them, the width is between two of them. sometimes the length is increasing but the width is not.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Description:**
# This is a jointplot of sepal width and length, it shows the distribution between these two variables, it shows the counts of observations that fall within hexagonal bins, so when the color of the bin gets darker and deeper, it means there is more the number of this kind of observation, and when the color getting light, there are fewer counts of this kind of observation. The bar chart on both sides also shows the distribution
#
#
# There are two centres in the plot, one of the most black bins is the sepal_length 6.0, sepal_width between 2.5-3.0, and the top left black bin is sepal_length 5.0, sepal_width 3.5

# %%
`         `
